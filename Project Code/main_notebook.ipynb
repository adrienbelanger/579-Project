# %% [markdown]
# # PPO on Atari57

# %% [markdown]
# Note for running @Eric3939 @su31kh: If you make any changes in the other python files, your python kernel might still have the older version of the functions in memory, so you might need to restart your kernel for it to run correctly.

# %% [markdown]
# ## Imports and Setup

# %%
import importlib
import gymnasium as gym
import ale_py # arcade learning environment, makes our atari games work for RL
import numpy as np
import pandas as pd
from typing import Literal
import gymnasium.wrappers # used in litterals

gym.register_envs(ale_py)

# ----------------- our code
from helpers import run_benchmark, plot_results
import agent
from game import Game, VALID_GAMES
import config

# %% [markdown]
# # Testing with random agent

# %%
ppo_agent = agent.PPOAgent()

random_agent =agent.RandomAgent()


plot_results(run_benchmark([ppo_agent, random_agent],["Alien"]))
# Out:
# Using agent PPOAgent - 1/2
#   Training agent PPOAgent on game Alien...
#     Training: 100%|██████████| 9/9 [01:05<00:00,  7.23s/update]
#   Evaluating agent PPOAgent on game Alien...
#      Seed 7 - 1/3
#      Seed 4002 - 2/3
#      Seed 451 - 3/3
# Using agent RandomAgent - 2/2
#   Evaluating agent RandomAgent on game Alien...
#      Seed 7 - 1/3
#      Seed 4002 - 2/3
#      Seed 451 - 3/3
