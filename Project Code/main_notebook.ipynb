# %% [markdown]
# # PPO on Atari57

# %% [markdown]
# Note for running @Eric3939 @su31kh: If you make any changes in the other python files, your python kernel might still have the older version of the functions in memory, so you might need to restart your kernel for it to run correctly.

# %% [markdown]
# ## Imports and Setup

# %%
import importlib
import gymnasium as gym
import ale_py # arcade learning environment, makes our atari games work for RL
import numpy as np
import pandas as pd
from typing import Literal
import gymnasium.wrappers # used in litterals

gym.register_envs(ale_py)

# ----------------- our code
from helpers import run_benchmark, plot_results
import agent

# %% [markdown]
# # Running Benchmarks

# %%
ppo_agent = agent.PPOAgent()
ppo_vf_anneal_agent = agent.PPOAgent_VF_Annealing()


run_benchmark([ppo_agent,ppo_vf_anneal_agent],["Alien"])
# Out:
# Using agent PPOAgent - 1/2
#   On game Alien, 1/1
#     Using seed 7 - 1/3
#       Training:   0%|          | 23/9765 [00:42<5:02:53,  1.87s/update]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 ppo_agent = agent.PPOAgent()
#       2 ppo_vf_anneal_agent = agent.PPOAgent_VF_Annealing()
# ----> 5 run_benchmark([ppo_agent,ppo_vf_anneal_agent],["Alien"])
#
# File ~/Library/GitHub/579-Project/Project Code/helpers.py:155, in run_benchmark(agents, games_list)
#     150 except TypeError as exc:
#     151     raise TypeError(
#     152         f"{agent.__class__.__name__} must support a zero-argument constructor to be used in run_benchmark."
#     153     ) from exc
# --> 155 episode_points = run_agent.train(game, seed=seed)
#     156 seed_result = seedResult(seed, episode_points)
#     157 seed_results.append(seed_result)
#
# File ~/Library/GitHub/579-Project/Project Code/agent.py:104, in PPOAgent.train(self, game, seed)
#     102 action_dim = int(vector_env.single_action_space.n) # type:ignore
#     103 self.model = self._build_model(action_dim)
# --> 104 episode_points = self.model.train(vector_env, seed=seed)
#     105 self._trained = True
#     106 self._trained_game = game.name
#
# File ~/Library/GitHub/579-Project/Project Code/model.py:130, in PPOModel.train(self, env, seed)
#     127 for group in self.optimizer.param_groups:
#     128     group["lr"] = lr
# --> 130 O, A, R, D, LP, V, obs, episode_returns, total_timesteps, new_points = self._rollout(
#     131     env,
#     132     obs,
#     133     episode_returns,
#     134     total_timesteps,
#     135 )
#     136 episode_points.extend(new_points)
#     137 with torch.no_grad():
#
# File ~/Library/GitHub/579-Project/Project Code/model.py:154, in PPOModel._rollout(self, env, obs, episode_returns, total_timesteps)
#     152     logits, values = self.network(obs)
#     153 dist = Categorical(logits=logits)
# --> 154 actions = dist.sample()
#     155 next_obs, rewards, terminated, truncated, _ = env.step(actions.cpu().numpy())
#     156 dones = np.logical_or(terminated, truncated)
#
# File ~/Library/GitHub/579-Project/.venv/lib/python3.13/site-packages/torch/distributions/categorical.py:148, in Categorical.sample(self, sample_shape)
#     146     sample_shape = torch.Size(sample_shape)
#     147 probs_2d = self.probs.reshape(-1, self._num_events)
# --> 148 samples_2d = torch.multinomial(probs_2d, sample_shape.numel(), True).T
#     149 return samples_2d.reshape(self._extended_shape(sample_shape))
#
# KeyboardInterrupt:
