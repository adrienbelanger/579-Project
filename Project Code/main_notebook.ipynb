# %% [markdown]
# # PPO on Atari57

# %% [markdown]
# Note for running @Eric3939 @su31kh: If you make any changes in the other python files, your python kernel might still have the older version of the functions in memory, so you might need to restart your kernel for it to run correctly.

# %% [markdown]
# ## Imports and Setup

# %%
import importlib
import gymnasium as gym
import ale_py # arcade learning environment, makes our atari games work for RL
import numpy as np
import pandas as pd
from typing import Literal
import gymnasium.wrappers # used in litterals

gym.register_envs(ale_py)

# ----------------- our code
from helpers import run_benchmark, plot_results
import agent

# %% [markdown]
# # Testing with random agent

# %%
ppo_agent = agent.PPOAgent()
ppo_vf_anneal_agent = agent.PPOAgent_VF_Annealing()


run_benchmark([ppo_agent,ppo_vf_anneal_agent],["Alien"])
# Out:
# Using agent PPOAgent - 1/2
#   On game Alien, 1/1
#     Using seed 7 - 1/3
#       Training: 100%|██████████| 97/97 [03:13<00:00,  1.99s/update]
#     Using seed 4002 - 2/3
#       Training: 100%|██████████| 97/97 [03:09<00:00,  1.95s/update]
#     Using seed 451 - 3/3
#       Training: 100%|██████████| 97/97 [03:08<00:00,  1.94s/update]
# Using agent PPOAgent_VF_Annealing - 2/2
#   On game Alien, 1/1
#     Using seed 7 - 1/3
#       Training: 100%|██████████| 97/97 [03:08<00:00,  1.94s/update]
#     Using seed 4002 - 2/3
#       Training: 100%|██████████| 97/97 [03:07<00:00,  1.94s/update]
#     Using seed 451 - 3/3
#       Training: 100%|██████████| 97/97 [03:21<00:00,  2.08s/update]
